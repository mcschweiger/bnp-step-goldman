# %%
import bnpstep as bnp

sampler = bnp.BNPStep()
sampler.load_data("data/ayush_data_20241220.csv", has_timepoints=False)
sampler.results_from_file('./your_results_file')

# %%
"""
Visualize your results. Figures will be shown below and saved to disk in BNP-Step's directory.

"""
sampler.visualize_results(['step', 'hist_step_height', 'hist_dwell_time', 'hist_emission', 'hist_eta'], datacolor='black', y_label = 'E_FRET', x_label = 'time [A.U.]')
# Out:
# /home/mcschwei/codes/stepfind/bnp-step-goldman/bnpstep.py:2053: UserWarning: eta histogram NYI
#   warnings.warn(f"eta histogram NYI", UserWarning)

# %%
sampler.results_to_file(outfile='hi_ayush', simple=True)
